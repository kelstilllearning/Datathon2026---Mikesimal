# %% [markdown]
# <a href="https://colab.research.google.com/github/kelstilllearning/Datathon2026---Mikesimal/blob/main/coba_coba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
mydataset = {
  'cars': ["Toyota", "Honda", "Hyundai"],
  'Jenis': ["Veloz", "HRV", "Stargazer"],
  'Harga(Dalam Juta Rupiah)': [385,387,306]
}

myvar = pd.DataFrame(mydataset)

print(myvar)
# Out:
#       cars      Jenis  Harga(Dalam Juta Rupiah)
# 0   Toyota      Veloz                       385
# 1    Honda        HRV                       387
# 2  Hyundai  Stargazer                       306

# %%
a = [28, 32, 87]

npm = pd.Series(a, index = ["Mikail", "Baliyan", "Faruqi"])

print(npm)
cari = input("Mau cari NPM siapa: ")
print(npm[cari])
# Out:
# Mikail     28
# Baliyan    32
# Faruqi     87
# dtype: int64
# Mau cari NPM siapa: Baliyan
# 32

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories)

print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

myvar = pd.DataFrame(data)

myvar
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
data_mahasiswa = [
     ["Mikail", 28 , 85],
     ["Baliyan", 32, 85],
    ["Faruqi", 87, 90]
]

df = pd.DataFrame(data_mahasiswa, columns = ["Nama", "NPM", "Nilai Kalkulus"])
print(df)
# Out:
#       Nama  NPM  Nilai Kalkulus
# 0   Mikail   28              85
# 1  Baliyan   32              85
# 2   Faruqi   87              90

# %%
print(df.loc[[0,1]])
# Out:
#       Nama  NPM  Nilai Kalkulus
# 0   Mikail   28              85
# 1  Baliyan   32              85

# %%
print(df.loc[0])
# Out:
# Nama              Mikail
# NPM                   28
# Nilai Kalkulus        85
# Name: 0, dtype: object

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data.csv')
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data.csv')

print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
print(pd.options.display.max_rows)
# Out:
# 9999

# %%
pd.options.display.max_rows = 9999

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data.csv')

print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
print(df.describe())
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
data = pd.read_json('/content/drive/MyDrive/Colab Notebooks/data.js')

print(data.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.5
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...
